# %% [markdown]
# ## Capstone: Airbnb in DC
# ## Modeling

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %matplotlib inline

# %% [markdown]
# ### Functions

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test):

    # Score model: R-squared (coefficient of determination)

    print('train R^2:', model.score(X_train, y_train))
    print('test R^2:', model.score(X_test, y_test))
    print('')

    # compare train & test RMSE (root mean squared error)

    y_pred_train = model.predict(X_train)
    train_mse = mean_squared_error(np.exp(y_train), np.exp(y_pred_train))
    train_rmse = np.sqrt(train_mse)

    y_pred_test = model.predict(X_test)
    test_mse = mean_squared_error(np.exp(y_test), np.exp(y_pred_test))
    test_rmse = np.sqrt(test_mse)

    print('train RMSE:', train_rmse)
    print('test RMSE:', test_rmse)
    print('')

    # compare train & test MAE (mean absolute error)

    y_pred_train = model.predict(X_train)
    train_mae = mean_absolute_error(np.exp(y_train), np.exp(y_pred_train))

    y_pred_test = model.predict(X_test)
    test_mae = mean_absolute_error(np.exp(y_test), np.exp(y_pred_test))

    print('train MAE:', train_mae)
    print('test MAE:', test_mae)

# %% [markdown]
# ### Import cleaned data

# %%
dflist = pd.read_csv('../data/airbnb01.csv')
dflist.shape
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (24,26,47,58,91,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (82942, 103)

# %% [markdown]
# ### Data preprocessing for linear regression

# %%
# numeric features
features_num = ['calculated_host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds',  
                'availability_365', 'number_of_reviews', 'review_scores_rating']

# categorical features
features_cat = ['host_is_superhost', 'neighbourhood_cleansed', 'zipcode', 'property_type', 'room_type', 'cancellation_policy']

# all features including target (log_price)
features = features_num + features_cat
features.extend(['log_price'])
features
# Out:
# ['calculated_host_listings_count',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'availability_365',
#  'number_of_reviews',
#  'review_scores_rating',
#  'host_is_superhost',
#  'neighbourhood_cleansed',
#  'zipcode',
#  'property_type',
#  'room_type',
#  'cancellation_policy',
#  'log_price']

# %%
X = dflist[features].dropna()
y = X['log_price']
X = X.drop(columns='log_price')

X = pd.get_dummies(X, columns=features_cat, drop_first=True)
X.head()
# Out:
#    calculated_host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0                              18             4        1.0       1.0   2.0
# 1                               1             6        3.0       3.0   3.0
# 3                               1             2        1.0       1.0   1.0
# 4                               1             4        1.0       1.0   1.0
# 5                               1             4        1.0       2.0   4.0
#
#    availability_365  number_of_reviews  review_scores_rating  \
# 0               283                  0                   0.0
# 1               343                 65                  94.0
# 3               365                  0                   0.0
# 4               351                  0                   0.0
# 5               361                  0                   0.0
#
#    host_is_superhost_t  neighbourhood_cleansed_Brookland, Brentwood, Langdon  \
# 0                    0                                                  0
# 1                    0                                                  0
# 3                    0                                                  0
# 4                    0                                                  0
# 5                    0                                                  0
#
#                   ...                   property_type_Serviced apartment  \
# 0                 ...                                                  0
# 1                 ...                                                  0
# 3                 ...                                                  0
# 4                 ...                                                  0
# 5                 ...                                                  0
#
#    property_type_Townhouse  property_type_other  room_type_Private room  \
# 0                        0                    0                       0
# 1                        0                    0                       0
# 3                        0                    0                       1
# 4                        1                    0                       0
# 5                        0                    1                       0
#
#    room_type_Shared room  cancellation_policy_moderate  \
# 0                      0                             0
# 1                      0                             0
# 3                      0                             0
# 4                      0                             0
# 5                      0                             0
#
#    cancellation_policy_strict  \
# 0                           0
# 1                           1
# 3                           0
# 4                           0
# 5                           0
#
#    cancellation_policy_strict_14_with_grace_period  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    cancellation_policy_super_strict_30  cancellation_policy_super_strict_60
# 0                                    0                                    0
# 1                                    0                                    0
# 3                                    0                                    0
# 4                                    0                                    0
# 5                                    0                                    0
#
# [5 rows x 76 columns]

# %%
X = dflist[features].dropna()
y = X['log_price']
X = X.drop(columns='log_price')

X = pd.get_dummies(X, columns=features_cat, drop_first=True)
X.head()
# Out:
#    calculated_host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0                              18             4        1.0       1.0   2.0
# 1                               1             6        3.0       3.0   3.0
# 3                               1             2        1.0       1.0   1.0
# 4                               1             4        1.0       1.0   1.0
# 5                               1             4        1.0       2.0   4.0
#
#    availability_365  number_of_reviews  review_scores_rating  \
# 0               283                  0                   0.0
# 1               343                 65                  94.0
# 3               365                  0                   0.0
# 4               351                  0                   0.0
# 5               361                  0                   0.0
#
#    host_is_superhost_t  neighbourhood_cleansed_Brookland, Brentwood, Langdon  \
# 0                    0                                                  0
# 1                    0                                                  0
# 3                    0                                                  0
# 4                    0                                                  0
# 5                    0                                                  0
#
#                   ...                   property_type_Serviced apartment  \
# 0                 ...                                                  0
# 1                 ...                                                  0
# 3                 ...                                                  0
# 4                 ...                                                  0
# 5                 ...                                                  0
#
#    property_type_Townhouse  property_type_other  room_type_Private room  \
# 0                        0                    0                       0
# 1                        0                    0                       0
# 3                        0                    0                       1
# 4                        1                    0                       0
# 5                        0                    1                       0
#
#    room_type_Shared room  cancellation_policy_moderate  \
# 0                      0                             0
# 1                      0                             0
# 3                      0                             0
# 4                      0                             0
# 5                      0                             0
#
#    cancellation_policy_strict  \
# 0                           0
# 1                           1
# 3                           0
# 4                           0
# 5                           0
#
#    cancellation_policy_strict_14_with_grace_period  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    cancellation_policy_super_strict_30  cancellation_policy_super_strict_60
# 0                                    0                                    0
# 1                                    0                                    0
# 3                                    0                                    0
# 4                                    0                                    0
# 5                                    0                                    0
#
# [5 rows x 76 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Standardize features to have mean = 0 and standard deviation = 1
# This is important for comparing features with different units or scales
# and also a general requirement for many machine learning algorithms.

ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %% [markdown]
# ### Baseline regression model

# %%
# Create Dummy Regression that always predicts the mean value of target
# ref: https://chrisalbon.com/machine_learning/model_evaluation/create_baseline_regression_model/

# Create a dummy regressor
dummy_mean = DummyRegressor(strategy='mean')

# "Train" dummy regressor
dummy_mean.fit(X_train_sc, y_train)

# Get R-squared (coefficient of determination)
print('baseline R^2:', dummy_mean.score(X_test_sc, y_test))

# get baseline RMSE (root mean squared error)
y_pred = dummy_mean.predict(X_test_sc)
mse = mean_squared_error(np.exp(y_test), np.exp(y_pred))
rmse = np.sqrt(mse)
print('baseline RMSE:', rmse)

# get baseline MAE (mean absolute error)
mae = mean_absolute_error(np.exp(y_test), np.exp(y_pred))
print('baseline MAE:', mae)
# Out:
# baseline R^2: -5.143814048769179e-05
# baseline RMSE: 393.1244874668375
# baseline MAE: 141.9438372966505

# %% [markdown]
# ### Model 01: Linear regression

# %%
# fit model
model = LinearRegression()
model.fit(X_train_sc, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
evaluate_model(model, X_train_sc, y_train, X_test_sc, y_test)
# Out:
# train R^2: 0.5665116260426284
# test R^2: 0.5664101819341408
#
# train RMSE: 304.6476528132647
# test RMSE: 331.0587985350242
#
# train MAE: 105.48749832225363
# test MAE: 107.24797471496684

# %% [markdown]
# ### Model 02: Lasso

# %%
# Instantiate model
lasso_model = LassoCV(cv=3)

# Fit model using best alpha
lasso_model = lasso_model.fit(X_train_sc, y_train)

# optimal value of alpha
lasso_model.alpha_
# Out:
# 0.0004103850950474946

# %%
evaluate_model(lasso_model, X_train_sc, y_train, X_test_sc, y_test)
# Out:
# train R^2: 0.5659975083788471
# test R^2: 0.5659293958876668
#
# train RMSE: 304.98919475309043
# test RMSE: 331.33616722949535
#
# train MAE: 105.51339964569439
# test MAE: 107.28701618277356

# %%
# look at coefficients

lasso_coefs = pd.DataFrame(data=lasso_model.coef_, index=X_train.columns, columns=['coef'])
lasso_coefs['abs_coef'] = np.abs(lasso_coefs['coef'])
lasso_coefs.sort_values('abs_coef', ascending=False)
# Out:
#                                                         coef  abs_coef
# review_scores_rating                               -0.241026  0.241026
# room_type_Private room                             -0.203300  0.203300
# bedrooms                                            0.189268  0.189268
# room_type_Shared room                              -0.187615  0.187615
# accommodates                                        0.181607  0.181607
# neighbourhood_cleansed_Downtown, Chinatown, Pen...  0.110560  0.110560
# neighbourhood_cleansed_Capitol Hill, Lincoln Park   0.102147  0.102147
# neighbourhood_cleansed_Shaw, Logan Circle           0.091821  0.091821
# bathrooms                                           0.089964  0.089964
# neighbourhood_cleansed_Union Station, Stanton P...  0.087670  0.087670
# beds                                               -0.080897  0.080897
# neighbourhood_cleansed_Dupont Circle, Connectic...  0.078078  0.078078
# neighbourhood_cleansed_West End, Foggy Bottom, GWU  0.072674  0.072674
# neighbourhood_cleansed_Southwest Employment Are...  0.060885  0.060885
# neighbourhood_cleansed_other                       -0.059359  0.059359
# neighbourhood_cleansed_Twining, Fairlawn, Randl... -0.058780  0.058780
# neighbourhood_cleansed_Howard University, Le Dr...  0.055956  0.055956
# availability_365                                    0.055391  0.055391
# zipcode_20007                                       0.051825  0.051825
# cancellation_policy_super_strict_60                -0.050588  0.050588
# calculated_host_listings_count                     -0.046279  0.046279
# zipcode_20020                                       0.041635  0.041635
# number_of_reviews                                  -0.041053  0.041053
# neighbourhood_cleansed_Congress Heights, Bellev... -0.039630  0.039630
# property_type_House                                 0.036507  0.036507
# neighbourhood_cleansed_Historic Anacostia          -0.036266  0.036266
# neighbourhood_cleansed_Capitol View, Marshall H... -0.033826  0.033826
# neighbourhood_cleansed_Woodridge, Fort Lincoln,... -0.032365  0.032365
# neighbourhood_cleansed_Near Southeast, Navy Yard    0.031478  0.031478
# neighbourhood_cleansed_Georgetown, Burleith/Hil...  0.030483  0.030483
# ...                                                      ...       ...
# zipcode_20008                                       0.020062  0.020062
# zipcode_20036                                       0.019465  0.019465
# neighbourhood_cleansed_Cleveland Park, Woodley ...  0.017997  0.017997
# property_type_Condominium                           0.016963  0.016963
# property_type_Guest suite                          -0.016751  0.016751
# zipcode_20005                                       0.016362  0.016362
# neighbourhood_cleansed_Cathedral Heights, McLea... -0.013039  0.013039
# property_type_Serviced apartment                    0.012081  0.012081
# neighbourhood_cleansed_Columbia Heights, Mt. Pl...  0.011017  0.011017
# property_type_Other                                 0.010770  0.010770
# cancellation_policy_strict                         -0.010754  0.010754
# zipcode_20016                                       0.010500  0.010500
# neighbourhood_cleansed_Spring Valley, Palisades...  0.008345  0.008345
# zipcode_20024                                      -0.007545  0.007545
# neighbourhood_cleansed_Colonial Village, Shephe... -0.006983  0.006983
# neighbourhood_cleansed_North Cleveland Park, Fo...  0.006622  0.006622
# property_type_Townhouse                            -0.006223  0.006223
# property_type_Loft                                  0.005554  0.005554
# host_is_superhost_t                                -0.003518  0.003518
# zipcode_20010                                       0.003253  0.003253
# zipcode_20002                                      -0.002759  0.002759
# property_type_other                                 0.002730  0.002730
# zipcode_20012                                       0.002594  0.002594
# zipcode_20003                                       0.002348  0.002348
# neighbourhood_cleansed_Hawthorne, Barnaby Woods...  0.001503  0.001503
# zipcode_20015                                      -0.001396  0.001396
# zipcode_20011                                      -0.001246  0.001246
# neighbourhood_cleansed_Ivy City, Arboretum, Tri... -0.000860  0.000860
# zipcode_20037                                      -0.000279  0.000279
# neighbourhood_cleansed_Friendship Heights, Amer...  0.000000  0.000000
#
# [76 rows x 2 columns]

# %%
# look at zero coefficients

lasso_coefs[lasso_coefs['abs_coef'] == 0]
# Out:
#                                                     coef  abs_coef
# neighbourhood_cleansed_Friendship Heights, Amer...   0.0       0.0

# %% [markdown]
# ### Data preprocessing for model 03

# %%
features.extend(['year_2015', 'year_2018', 'q_2', 'q_3', 'q_4'])
X = dflist[features].dropna()
y = X['log_price']
X = X.drop(columns='log_price')

X = pd.get_dummies(X, columns=features_cat, drop_first=True)
X.head()
# Out:
#    calculated_host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0                              18             4        1.0       1.0   2.0
# 1                               1             6        3.0       3.0   3.0
# 3                               1             2        1.0       1.0   1.0
# 4                               1             4        1.0       1.0   1.0
# 5                               1             4        1.0       2.0   4.0
#
#    availability_365  number_of_reviews  review_scores_rating  year_2015  \
# 0               283                  0                   0.0          1
# 1               343                 65                  94.0          1
# 3               365                  0                   0.0          1
# 4               351                  0                   0.0          1
# 5               361                  0                   0.0          1
#
#    year_2018                 ...                   \
# 0          0                 ...
# 1          0                 ...
# 3          0                 ...
# 4          0                 ...
# 5          0                 ...
#
#    property_type_Serviced apartment  property_type_Townhouse  \
# 0                                 0                        0
# 1                                 0                        0
# 3                                 0                        0
# 4                                 0                        1
# 5                                 0                        0
#
#    property_type_other  room_type_Private room  room_type_Shared room  \
# 0                    0                       0                      0
# 1                    0                       0                      0
# 3                    0                       1                      0
# 4                    0                       0                      0
# 5                    1                       0                      0
#
#    cancellation_policy_moderate  cancellation_policy_strict  \
# 0                             0                           0
# 1                             0                           1
# 3                             0                           0
# 4                             0                           0
# 5                             0                           0
#
#    cancellation_policy_strict_14_with_grace_period  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    cancellation_policy_super_strict_30  cancellation_policy_super_strict_60
# 0                                    0                                    0
# 1                                    0                                    0
# 3                                    0                                    0
# 4                                    0                                    0
# 5                                    0                                    0
#
# [5 rows x 81 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

# %% [markdown]
# ### Model 03: Lasso (with time features)

# %%
# Instantiate model
lasso_model = LassoCV(cv=3)

# Fit model using best alpha
lasso_model = lasso_model.fit(X_train_sc, y_train)

# optimal value of alpha
lasso_model.alpha_
# Out:
# 0.0004103850950474946

# %%
evaluate_model(lasso_model, X_train_sc, y_train, X_test_sc, y_test)
# Out:
# train R^2: 0.5679197167645623
# test R^2: 0.5675369115322966
#
# train RMSE: 304.2621516245557
# test RMSE: 330.82651264691464
#
# train MAE: 105.21655130504932
# test MAE: 107.03556963017107

# %%
# look at coefficients

lasso_coefs = pd.DataFrame(data=lasso_model.coef_, index=X_train.columns, columns=['coef'])
lasso_coefs['abs_coef'] = np.abs(lasso_coefs['coef'])
lasso_coefs.sort_values('abs_coef', ascending=False)
# Out:
#                                                         coef  abs_coef
# review_scores_rating                               -0.239697  0.239697
# room_type_Private room                             -0.203378  0.203378
# bedrooms                                            0.189527  0.189527
# room_type_Shared room                              -0.187872  0.187872
# accommodates                                        0.180149  0.180149
# neighbourhood_cleansed_Downtown, Chinatown, Pen...  0.109824  0.109824
# neighbourhood_cleansed_Capitol Hill, Lincoln Park   0.101238  0.101238
# neighbourhood_cleansed_Shaw, Logan Circle           0.091110  0.091110
# bathrooms                                           0.090239  0.090239
# neighbourhood_cleansed_Union Station, Stanton P...  0.086829  0.086829
# beds                                               -0.080611  0.080611
# neighbourhood_cleansed_Dupont Circle, Connectic...  0.077643  0.077643
# neighbourhood_cleansed_West End, Foggy Bottom, GWU  0.072551  0.072551
# neighbourhood_cleansed_other                       -0.060721  0.060721
# neighbourhood_cleansed_Southwest Employment Are...  0.060081  0.060081
# availability_365                                    0.059939  0.059939
# neighbourhood_cleansed_Twining, Fairlawn, Randl... -0.059464  0.059464
# neighbourhood_cleansed_Howard University, Le Dr...  0.055188  0.055188
# zipcode_20007                                       0.051508  0.051508
# cancellation_policy_super_strict_60                -0.049810  0.049810
# calculated_host_listings_count                     -0.047663  0.047663
# zipcode_20020                                       0.042417  0.042417
# number_of_reviews                                  -0.041410  0.041410
# neighbourhood_cleansed_Congress Heights, Bellev... -0.040046  0.040046
# neighbourhood_cleansed_Historic Anacostia          -0.036868  0.036868
# property_type_House                                 0.035988  0.035988
# neighbourhood_cleansed_Capitol View, Marshall H... -0.034736  0.034736
# neighbourhood_cleansed_Woodridge, Fort Lincoln,... -0.032958  0.032958
# year_2015                                          -0.032122  0.032122
# neighbourhood_cleansed_Near Southeast, Navy Yard    0.031150  0.031150
# ...                                                      ...       ...
# cancellation_policy_strict                         -0.016843  0.016843
# zipcode_20005                                       0.016787  0.016787
# property_type_Condominium                           0.016609  0.016609
# property_type_Guest suite                          -0.015851  0.015851
# neighbourhood_cleansed_Cathedral Heights, McLea... -0.013442  0.013442
# property_type_Serviced apartment                    0.012451  0.012451
# property_type_Other                                 0.010818  0.010818
# zipcode_20016                                       0.010437  0.010437
# neighbourhood_cleansed_Columbia Heights, Mt. Pl...  0.010285  0.010285
# q_4                                                -0.008236  0.008236
# neighbourhood_cleansed_Spring Valley, Palisades...  0.008018  0.008018
# zipcode_20024                                      -0.007273  0.007273
# neighbourhood_cleansed_Colonial Village, Shephe... -0.007075  0.007075
# neighbourhood_cleansed_North Cleveland Park, Fo...  0.006228  0.006228
# property_type_Townhouse                            -0.005968  0.005968
# property_type_Loft                                  0.005772  0.005772
# host_is_superhost_t                                -0.004434  0.004434
# q_2                                                 0.003560  0.003560
# q_3                                                -0.003366  0.003366
# zipcode_20010                                       0.003353  0.003353
# zipcode_20002                                      -0.003164  0.003164
# zipcode_20003                                       0.002604  0.002604
# property_type_other                                 0.002295  0.002295
# zipcode_20011                                      -0.002121  0.002121
# zipcode_20012                                       0.001927  0.001927
# zipcode_20015                                      -0.001381  0.001381
# neighbourhood_cleansed_Ivy City, Arboretum, Tri... -0.001158  0.001158
# neighbourhood_cleansed_Hawthorne, Barnaby Woods...  0.000999  0.000999
# zipcode_20037                                      -0.000195  0.000195
# neighbourhood_cleansed_Friendship Heights, Amer... -0.000000  0.000000
#
# [81 rows x 2 columns]

# %%
# look at zero coefficients

lasso_coefs[lasso_coefs['abs_coef'] == 0]
# Out:
#                                                     coef  abs_coef
# neighbourhood_cleansed_Friendship Heights, Amer...  -0.0       0.0

# %% [markdown]
# ### Data preprocessing for model 04

# %%
X = dflist[features].dropna()
y = X['log_price']
X = X.drop(columns='log_price')

X = pd.get_dummies(X, columns=features_cat, drop_first=True)
X.head()
# Out:
#    calculated_host_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0                              18             4        1.0       1.0   2.0
# 1                               1             6        3.0       3.0   3.0
# 3                               1             2        1.0       1.0   1.0
# 4                               1             4        1.0       1.0   1.0
# 5                               1             4        1.0       2.0   4.0
#
#    availability_365  number_of_reviews  review_scores_rating  year_2015  \
# 0               283                  0                   0.0          1
# 1               343                 65                  94.0          1
# 3               365                  0                   0.0          1
# 4               351                  0                   0.0          1
# 5               361                  0                   0.0          1
#
#    year_2018                 ...                   \
# 0          0                 ...
# 1          0                 ...
# 3          0                 ...
# 4          0                 ...
# 5          0                 ...
#
#    property_type_Serviced apartment  property_type_Townhouse  \
# 0                                 0                        0
# 1                                 0                        0
# 3                                 0                        0
# 4                                 0                        1
# 5                                 0                        0
#
#    property_type_other  room_type_Private room  room_type_Shared room  \
# 0                    0                       0                      0
# 1                    0                       0                      0
# 3                    0                       1                      0
# 4                    0                       0                      0
# 5                    1                       0                      0
#
#    cancellation_policy_moderate  cancellation_policy_strict  \
# 0                             0                           0
# 1                             0                           1
# 3                             0                           0
# 4                             0                           0
# 5                             0                           0
#
#    cancellation_policy_strict_14_with_grace_period  \
# 0                                                0
# 1                                                0
# 3                                                0
# 4                                                0
# 5                                                0
#
#    cancellation_policy_super_strict_30  cancellation_policy_super_strict_60
# 0                                    0                                    0
# 1                                    0                                    0
# 3                                    0                                    0
# 4                                    0                                    0
# 5                                    0                                    0
#
# [5 rows x 81 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# to reduce total number of polynomial features:
# include interaction terms only (not squared terms) 
poly = PolynomialFeatures(interaction_only=True)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.fit_transform(X_test)

# %%
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train_poly)
X_test_sc = ss.transform(X_test_poly)

# %% [markdown]
# ### Model 04: Lasso (with polynomial features)

# %%
# Instantiate model
lasso_model = LassoCV(cv=3)

# Fit model using best alpha
lasso_model = lasso_model.fit(X_train_sc, y_train)

# optimal value of alpha
lasso_model.alpha_
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.00041038509504750636

# %%
evaluate_model(lasso_model, X_train_sc, y_train, X_test_sc, y_test)
# Out:
# train R^2: 0.6557417109384336
# test R^2: 0.6451750458361454
#
# train RMSE: 268.70595444503414
# test RMSE: 297.2311919155132
#
# train MAE: 92.70622024405951
# test MAE: 95.99006562887536

# %%
# look at coefficients

lasso_coefs = pd.DataFrame(poly.get_feature_names(X_train.columns))
lasso_coefs['coef'] = lasso_model.coef_
lasso_coefs['abs_coef'] = np.abs(lasso_coefs['coef'])
lasso_coefs.sort_values('abs_coef', ascending=False)
# Out:
#                                                       0      coef  abs_coef
# 2                                          accommodates  0.447982  0.447982
# 8                                  review_scores_rating -0.229277  0.229277
# 167                   accommodates review_scores_rating -0.216619  0.216619
# 7                                     number_of_reviews -0.182784  0.182784
# 75                               room_type_Private room -0.158738  0.158738
# 3                                             bathrooms  0.156852  0.156852
# 162                              accommodates bathrooms -0.147533  0.147533
# 626            review_scores_rating host_is_superhost_t  0.145233  0.145233
# 547              number_of_reviews review_scores_rating  0.141494  0.141494
# 14                                  host_is_superhost_t -0.138282  0.138282
# 313                     bathrooms room_type_Shared room -0.128842  0.128842
# 23    neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.128120  0.128120
# 4                                              bedrooms  0.122209  0.122209
# 312                    bathrooms room_type_Private room -0.120135  0.120135
# 1                        calculated_host_listings_count -0.114702  0.114702
# 398                           beds review_scores_rating  0.098347  0.098347
# 88    calculated_host_listings_count review_scores_r...  0.093367  0.093367
# 68                            property_type_Guest suite -0.092226  0.092226
# 680      review_scores_rating property_type_Guest suite  0.088358  0.088358
# 42    neighbourhood_cleansed_Union Station, Stanton ...  0.081273  0.081273
# 685        review_scores_rating property_type_Townhouse  0.080609  0.080609
# 621                      review_scores_rating year_2015  0.074315  0.074315
# 156   calculated_host_listings_count room_type_Share... -0.073925  0.073925
# 234                 accommodates room_type_Private room  0.072702  0.072702
# 242                                      bathrooms beds  0.067040  0.067040
# 215                          accommodates zipcode_20016  0.065127  0.065127
# 6                                      availability_365  0.063885  0.063885
# 687         review_scores_rating room_type_Private room  0.063200  0.063200
# 73                              property_type_Townhouse -0.063089  0.063089
# 85                  calculated_host_listings_count beds  0.060477  0.060477
# ...                                                 ...       ...       ...
# 1645  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1646  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1647  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1650  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1640  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1651  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1653  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1655  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1664  neighbourhood_cleansed_Downtown, Chinatown, Pe... -0.000000  0.000000
# 1665  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1667  neighbourhood_cleansed_Downtown, Chinatown, Pe... -0.000000  0.000000
# 1641  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1639  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1622  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1629  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1623  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1624  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1625  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1626  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1627  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1628  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1630  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1638  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1631  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1632  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1634  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1635  neighbourhood_cleansed_Downtown, Chinatown, Pe... -0.000000  0.000000
# 1636  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 1637  neighbourhood_cleansed_Downtown, Chinatown, Pe...  0.000000  0.000000
# 3321  cancellation_policy_super_strict_30 cancellati...  0.000000  0.000000
#
# [3322 rows x 3 columns]

# %%
# look at zero coefficients

lasso_coefs[lasso_coefs['abs_coef'] == 0]
# Out:
#                                                       0  coef  abs_coef
# 0                                                     1   0.0       0.0
# 12                                                  q_3  -0.0       0.0
# 15    neighbourhood_cleansed_Brookland, Brentwood, L...   0.0       0.0
# 19    neighbourhood_cleansed_Cleveland Park, Woodley...   0.0       0.0
# 25    neighbourhood_cleansed_Edgewood, Bloomingdale,...   0.0       0.0
# 27    neighbourhood_cleansed_Georgetown, Burleith/Hi...   0.0       0.0
# 29            neighbourhood_cleansed_Historic Anacostia  -0.0       0.0
# 35    neighbourhood_cleansed_North Cleveland Park, F...  -0.0       0.0
# 36    neighbourhood_cleansed_North Michigan Park, Mi...  -0.0       0.0
# 38    neighbourhood_cleansed_Southwest Employment Ar...   0.0       0.0
# 40    neighbourhood_cleansed_Takoma, Brightwood, Man...   0.0       0.0
# 41    neighbourhood_cleansed_Twining, Fairlawn, Rand...   0.0       0.0
# 45                         neighbourhood_cleansed_other   0.0       0.0
# 46                                        zipcode_20002  -0.0       0.0
# 49                                        zipcode_20007  -0.0       0.0
# 50                                        zipcode_20008  -0.0       0.0
# 52                                        zipcode_20010  -0.0       0.0
# 54                                        zipcode_20012  -0.0       0.0
# 55                                        zipcode_20015  -0.0       0.0
# 57                                        zipcode_20017   0.0       0.0
# 59                                        zipcode_20019   0.0       0.0
# 62                                        zipcode_20032  -0.0       0.0
# 64                                        zipcode_20037   0.0       0.0
# 65                                        zipcode_other   0.0       0.0
# 66                      property_type_Bed and breakfast   0.0       0.0
# 69                                  property_type_House  -0.0       0.0
# 70                                   property_type_Loft   0.0       0.0
# 74                                  property_type_other  -0.0       0.0
# 78                           cancellation_policy_strict  -0.0       0.0
# 81                  cancellation_policy_super_strict_60  -0.0       0.0
# ...                                                 ...   ...       ...
# 3266  property_type_Loft cancellation_policy_super_s...   0.0       0.0
# 3267  property_type_Other property_type_Serviced apa...   0.0       0.0
# 3268        property_type_Other property_type_Townhouse   0.0       0.0
# 3269            property_type_Other property_type_other   0.0       0.0
# 3276  property_type_Other cancellation_policy_super_...   0.0       0.0
# 3277  property_type_Serviced apartment property_type...   0.0       0.0
# 3278  property_type_Serviced apartment property_type...   0.0       0.0
# 3284  property_type_Serviced apartment cancellation_...  -0.0       0.0
# 3285  property_type_Serviced apartment cancellation_...   0.0       0.0
# 3286        property_type_Townhouse property_type_other   0.0       0.0
# 3287     property_type_Townhouse room_type_Private room  -0.0       0.0
# 3289  property_type_Townhouse cancellation_policy_mo...  -0.0       0.0
# 3293  property_type_Townhouse cancellation_policy_su...   0.0       0.0
# 3295          property_type_other room_type_Shared room  -0.0       0.0
# 3299  property_type_other cancellation_policy_super_...   0.0       0.0
# 3300  property_type_other cancellation_policy_super_...   0.0       0.0
# 3301       room_type_Private room room_type_Shared room   0.0       0.0
# 3306  room_type_Private room cancellation_policy_sup...   0.0       0.0
# 3310  room_type_Shared room cancellation_policy_supe...   0.0       0.0
# 3311  room_type_Shared room cancellation_policy_supe...   0.0       0.0
# 3312  cancellation_policy_moderate cancellation_poli...   0.0       0.0
# 3313  cancellation_policy_moderate cancellation_poli...   0.0       0.0
# 3314  cancellation_policy_moderate cancellation_poli...   0.0       0.0
# 3315  cancellation_policy_moderate cancellation_poli...   0.0       0.0
# 3316  cancellation_policy_strict cancellation_policy...   0.0       0.0
# 3317  cancellation_policy_strict cancellation_policy...   0.0       0.0
# 3318  cancellation_policy_strict cancellation_policy...   0.0       0.0
# 3319  cancellation_policy_strict_14_with_grace_perio...   0.0       0.0
# 3320  cancellation_policy_strict_14_with_grace_perio...   0.0       0.0
# 3321  cancellation_policy_super_strict_30 cancellati...   0.0       0.0
#
# [1936 rows x 3 columns]

# %% [markdown]
# ### Final model and create predictions

# %%
X = dflist[features].dropna()
y = X['log_price']
X = X.drop(columns='log_price')

X = pd.get_dummies(X, columns=features_cat, drop_first=True)
X.shape
# Out:
# (80649, 81)

# %%
# to reduce total number of polynomial features:
# include interaction terms only (not squared terms) 
poly = PolynomialFeatures(interaction_only=True)
X_poly = poly.fit_transform(X)

# %%
ss = StandardScaler()
X_sc = ss.fit_transform(X_poly)

# %%
# Instantiate model
lasso_model = LassoCV(cv=3)

# Fit model using best alpha
lasso_model = lasso_model.fit(X_sc, y)

# optimal value of alpha
lasso_model.alpha_
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0.0010870747187579346

# %%
# Get R-squared (coefficient of determination)
print('R^2:', lasso_model.score(X_sc, y))

# RMSE (root mean squared error)
y_pred = lasso_model.predict(X_sc)
mse = mean_squared_error(np.exp(y), np.exp(y_pred))
rmse = np.sqrt(mse)
print('RMSE:', rmse)

# MAE (mean absolute error)
mae = mean_absolute_error(np.exp(y), np.exp(y_pred))
print('MAE:', mae)
# Out:
# R^2: 0.6454394003587867
# RMSE: 278.54784339596824
# MAE: 94.85770012771434
