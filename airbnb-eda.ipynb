# %% [markdown]
# ## Capstone: Airbnb in DC
# ## Data Cleaning & EDA

# %% [markdown]
# ### Data source
#
# http://insideairbnb.com/get-the-data.html
# Inside Airbnb scraped data for Washington DC on these dates:
# - 11/15/18
# - 10/12/18
# - 9/14/18
# - 8/18/18
# - 7/20/18
# - 5/18/18
# - 4/15/18
# - 5/10/17
# - 3/10/17
# - 10/3/15
#
# Calendar/price data starts on date scraped

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Functions

# %%
# clean price: turn non-null prices from string to float

def clean_price(df_clean):
    df_clean['price'] = df_clean['price'].map(lambda s: s.strip('$') if (type(s) is str) else s) # if checks for NaNs
    df_clean['price'] = df_clean['price'].map(lambda s: s.replace(',', '') if (type(s) is str) else s) # if checks for NaNs
    df_clean['price'] = df_clean['price'].astype('float64')

# %%
# turn 'zipcode' from float to string

def clean_zipcode(df_clean):
    df_clean['zipcode'] = df_clean['zipcode'].map(lambda x: str(x).split('.')[0])
    df_clean['zipcode'] = df_clean['zipcode'].map(lambda x: str(x).split('-')[0])
    df_clean['zipcode'] = df_clean['zipcode'].replace('nan', np.nan)
    df_clean['zipcode'] = df_clean['zipcode'].replace(r'^\s+$', np.nan, regex=True) # from https://stackoverflow.com/questions/13445241/replacing-blank-values-white-space-with-nan-in-pandas

# %%
# set null 'review_scores_rating' to 0 for listings where 'number_of_reviews' == 0]

def clean_review_scores_rating(df_clean):
    filter_noreviews = df_clean['number_of_reviews'] == 0
    df_clean.loc[filter_noreviews, 'review_scores_rating'] = 0

# %%
# create variable 'year' and dummy variables 'year_2015' and 'year_2018'

def get_years(df):
    df['year'] = df['scrape_id'].map(lambda s: str(s)[0:4])
    df['year_2015'] = df['year'].map({'2015':1, '2017':0, '2018':0})
    df['year_2018'] = df['year'].map({'2015':0, '2017':0, '2018':1})

# %%
# create dummy variables 'q_2', 'q_3' and 'q_4'

def get_quarters(df):
    q_2 = {20151002231825:0, 20170310074739:0, 20170510175449:1, 20180415141347:1, 20180518061138:1, 
           20180720044642:0, 20180818154049:0, 20180914083845:0, 20181012035004:0, 20181115100708:0}
    q_3 = {20151002231825:0, 20170310074739:0, 20170510175449:0, 20180415141347:0, 20180518061138:0, 
           20180720044642:1, 20180818154049:1, 20180914083845:1, 20181012035004:0, 20181115100708:0}
    q_4 = {20151002231825:1, 20170310074739:0, 20170510175449:0, 20180415141347:0, 20180518061138:0, 
           20180720044642:0, 20180818154049:0, 20180914083845:0, 20181012035004:1, 20181115100708:1}
    df['q_2'] = df['scrape_id'].map(q_2)
    df['q_3'] = df['scrape_id'].map(q_3)
    df['q_4'] = df['scrape_id'].map(q_4)

# %%
# set categorical variable values that occur less than the threshold frequency to 'other'
# ref: https://stackoverflow.com/questions/35041628/conditionally-create-an-other-category-in-categorical-column

def cat_other(df, col, threshold):
    filter_cat = df[col].value_counts(normalize=True) < threshold
    df.loc[df[col].isin((df[col].value_counts()[filter_cat]).index), col] = 'other'

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test):

    # Score model: R-squared (coefficient of determination)

    print('train R^2:', model.score(X_train, y_train))
    print('test R^2:', model.score(X_test, y_test))
    print('')

    # compare train & test RMSE (root mean squared error)

    y_pred_train = model.predict(X_train)
    train_mse = mean_squared_error(np.exp(y_train), np.exp(y_pred_train))
    train_rmse = np.sqrt(train_mse)

    y_pred_test = model.predict(X_test)
    test_mse = mean_squared_error(np.exp(y_test), np.exp(y_pred_test))
    test_rmse = np.sqrt(test_mse)

    print('train RMSE:', train_rmse)
    print('test RMSE:', test_rmse)
    print('')

    # compare train & test MAE (mean absolute error)

    y_pred_train = model.predict(X_train)
    train_mae = mean_absolute_error(np.exp(y_train), np.exp(y_pred_train))

    y_pred_test = model.predict(X_test)
    test_mae = mean_absolute_error(np.exp(y_test), np.exp(y_pred_test))

    print('train MAE:', train_mae)
    print('test MAE:', test_mae)

# %% [markdown]
# ### Import all listing data files

# %%
dflist_15Oct = pd.read_csv('../data/2015-10/2015-10-listings.csv')
dflist_17Mar = pd.read_csv('../data/2017-03/2017-03-listings.csv')
dflist_17May = pd.read_csv('../data/2017-05/2017-05-listings.csv')
dflist_18Apr = pd.read_csv('../data/2018-04/2018-04-listings.csv')
dflist_18May = pd.read_csv('../data/2018-05/2018-05-listings.csv')
dflist_18Jul = pd.read_csv('../data/2018-07/2018-07-listings.csv')
dflist_18Aug = pd.read_csv('../data/2018-08/2018-08-listings.csv')
dflist_18Sep = pd.read_csv('../data/2018-09/2018-09-listings.csv')
dflist_18Oct = pd.read_csv('../data/2018-10/2018-10-listings.csv')
dflist_18Nov = pd.read_csv('../data/2018-11/2018-11-listings.csv')
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (43,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/envs/dsi/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dflists_all = [dflist_15Oct, dflist_17Mar, dflist_17May, dflist_18Apr, dflist_18May, dflist_18Jul, dflist_18Aug, dflist_18Sep, 
           dflist_18Oct, dflist_18Nov]

# %%
# concatenate listing files into one dataframe

dflist = pd.concat(dflists_all, sort=True)
dflist.shape
# Out:
# (82955, 96)

# %%
dflist.head()
# Out:
#   access  accommodates                                          amenities  \
# 0    NaN             4  {TV,"Wireless Internet","Air Conditioning",Kit...
# 1    NaN             6  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2    NaN             1  {"Cable TV","Wireless Internet","Air Condition...
# 3    NaN             2  {TV,Internet,"Wireless Internet","Air Conditio...
# 4    NaN             4  {TV,Internet,"Wireless Internet","Air Conditio...
#
#    availability_30  availability_365  availability_60  availability_90  \
# 0                0               283                0                8
# 1               12               343               38               68
# 2                0                60               30               60
# 3               30               365               60               90
# 4               16               351               46               76
#
#    bathrooms  bed_type  bedrooms   ...    \
# 0        1.0  Real Bed       1.0   ...
# 1        3.0  Real Bed       3.0   ...
# 2        2.0  Real Bed       1.0   ...
# 3        1.0  Real Bed       1.0   ...
# 4        1.0  Real Bed       1.0   ...
#
#                                                space  square_feet state  \
# 0                                                NaN          NaN    DC
# 1  Beautifully renovated Capitol Hill townhouse. ...          NaN    DC
# 2                                                NaN          NaN    MD
# 3                                                NaN          NaN    DC
# 4  This is a 750 sq ft 1 bedroom 1 bathroom.  Whi...          NaN    MD
#
#                                               street  \
# 0  3rd Street Southeast, Washington, DC 20003, Un...
# 1  11th Street Southeast, Washington, DC 20003, U...
# 2   14th Place, Hyattsville, MD 20782, United States
# 3          O St, Washington, DC 20024, United States
# 4  East-West Highway, Silver Spring, MD 20910, Un...
#
#                                              summary  \
# 0  Professional pictures coming soon! Welcome to ...
# 1                                                NaN
# 2  This is an ideal room for a single traveler th...
# 3  Prime location right on the Potomac River in W...
# 4  Hi travellers! I live in this peaceful spot, b...
#
#                                        thumbnail_url  \
# 0  https://a2.muscache.com/ac/pictures/105507202/...
# 1  https://a2.muscache.com/ac/pictures/14613245/d...
# 2  https://a1.muscache.com/ac/pictures/104989386/...
# 3  https://a2.muscache.com/ac/pictures/106977751/...
# 4  https://a2.muscache.com/ac/pictures/107730164/...
#
#                                              transit weekly_price  \
# 0                                                NaN    $1,125.00
# 1                                                NaN          NaN
# 2                                                NaN      $300.00
# 3                                                NaN          NaN
# 4  You can walk to the bus stop (1 min) Subway AN...      $400.00
#
#                                       xl_picture_url zipcode
# 0  https://a2.muscache.com/ac/pictures/105507202/...   20003
# 1  https://a2.muscache.com/ac/pictures/14613245/d...   20003
# 2  https://a1.muscache.com/ac/pictures/104989386/...   20782
# 3  https://a2.muscache.com/ac/pictures/106977751/...   20024
# 4  https://a2.muscache.com/ac/pictures/107730164/...   20910
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Features

# %%
# numeric features
features_num = ['calculated_host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds',  
                'availability_365', 'number_of_reviews', 'review_scores_rating']

# categorical features
features_cat = ['host_is_superhost', 'neighbourhood_cleansed', 'zipcode', 'property_type', 'room_type', 'cancellation_policy']

# all features including target (price)
features = features_num + features_cat
features.extend(['price'])
features
# Out:
# ['calculated_host_listings_count',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'availability_365',
#  'number_of_reviews',
#  'review_scores_rating',
#  'host_is_superhost',
#  'neighbourhood_cleansed',
#  'zipcode',
#  'property_type',
#  'room_type',
#  'cancellation_policy',
#  'price']

# %%
dflist[features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82955 entries, 0 to 9368
# Data columns (total 15 columns):
# calculated_host_listings_count    82955 non-null int64
# accommodates                      82955 non-null int64
# bathrooms                         82832 non-null float64
# bedrooms                          82858 non-null float64
# beds                              82820 non-null float64
# availability_365                  82955 non-null int64
# number_of_reviews                 82955 non-null int64
# review_scores_rating              62058 non-null float64
# host_is_superhost                 82921 non-null object
# neighbourhood_cleansed            82955 non-null object
# zipcode                           82008 non-null object
# property_type                     82954 non-null object
# room_type                         82955 non-null object
# cancellation_policy               82955 non-null object
# price                             82955 non-null object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 10.1+ MB

# %%
dflist[features].isnull().sum()
# Out:
# calculated_host_listings_count        0
# accommodates                          0
# bathrooms                           123
# bedrooms                             97
# beds                                135
# availability_365                      0
# number_of_reviews                     0
# review_scores_rating              20897
# host_is_superhost                    34
# neighbourhood_cleansed                0
# zipcode                             947
# property_type                         1
# room_type                             0
# cancellation_policy                   0
# price                                 0
# dtype: int64

# %% [markdown]
# ### Data cleaning

# %%
# clean price, zipcode, review_scores_rating
clean_price(dflist)
clean_zipcode(dflist)
clean_review_scores_rating(dflist)

# %%
# create variables for year and quarter
get_years(dflist)
get_quarters(dflist)

# %%
# decrease number of categories (to decrease number of polynomial features later)
cat_other(dflist, 'neighbourhood_cleansed', 0.005)
cat_other(dflist, 'zipcode', 0.005)
cat_other(dflist, 'property_type', 0.005)

# %% [markdown]
# ### Price distribution

# %%
dflist['price'].describe()
# Out:
# count    82955.000000
# mean       217.674607
# std        364.992818
# min          0.000000
# 25%         80.000000
# 50%        120.000000
# 75%        200.000000
# max      13000.000000
# Name: price, dtype: float64

# %%
dflist['price'].hist();

# %%
dflist['price'].hist(bins=100, figsize=(16,4));

# %%
dflist['price'].hist(bins=[0,25,50,75,100,125,150,175,200,225,250,275,300,325,350,375,400,425,450])
plt.title('Distribution of prices below $450');

# %%
# price has positive skew (the right tail is longer)
# look at skewness
dflist['price'].skew()
# Out:
# 9.351691080059926

# %%
# look at outliers (low)

dflist[dflist['price'] == 0]
# Out:
#                                                  access  accommodates  \
# 3832  Front and back screened-in porches, yard, Wifi...             5
# 7787  You will have access to the backyard, basement...             2
# 6335  You will have access to the backyard, basement...             2
# 7281  You will have access to the living room and en...             5
# 7283                                    Shared bathroom             2
# 7599  At the moment guests only have access to the r...             2
# 8152  The room has a lock on the door, plenty of spa...             3
# 8281  The room has a lock on the door, plenty of spa...             3
# 7165  At the moment guests only have access to the r...             2
# 6961  At the moment guests only have access to the r...             2
# 6942  At the moment guests only have access to the r...             2
# 6797  At the moment guests only have access to the r...             2
# 6689  At the moment guests only have access to the r...             2
#
#                                               amenities  availability_30  \
# 3832  {TV,"Cable TV",Internet,"Wireless Internet","A...               24
# 7787  {TV,Internet,"Wireless Internet","Air conditio...               24
# 6335  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...                0
# 7281  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                0
# 7283  {Wifi,"Air conditioning",Kitchen,Heating,Washe...                0
# 7599  {TV,"Air conditioning",Heating,Essentials,Sham...               10
# 8152  {TV,Wifi,"Air conditioning",Pool,Kitchen,Gym,E...               29
# 8281  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...               15
# 7165  {TV,"Air conditioning",Heating,Essentials,Sham...                4
# 6961  {TV,"Air conditioning",Heating,Essentials,Sham...                8
# 6942  {TV,"Air conditioning",Heating,Essentials,Sham...               22
# 6797  {TV,"Air conditioning",Heating,Essentials,Sham...               14
# 6689  {TV,"Air conditioning",Heating,Essentials,Sham...                0
#
#       availability_365  availability_60  availability_90  bathrooms  bed_type  \
# 3832               340               48               68        1.5  Real Bed
# 7787               359               54               84        1.0  Real Bed
# 6335                 0                0                0        1.0  Real Bed
# 7281                99                0                0        2.0  Real Bed
# 7283                13                0               13        1.0  Real Bed
# 7599                50               23               50        1.0  Real Bed
# 8152               364               59               89        1.0  Real Bed
# 8281               350               45               75        1.0  Real Bed
# 7165                49               24               49        1.0  Real Bed
# 6961                61               31               61        1.0  Real Bed
# 6942                78               48               78        1.0  Real Bed
# 6797                72               42               72        1.0  Real Bed
# 6689                 0                0                0        1.0  Real Bed
#
#       bedrooms ...                                            transit  \
# 3832       2.0 ...                Takoma Metro Station 4 blocks away.
# 7787       1.0 ...  Again as mentioned above there is two trains s...
# 6335       1.0 ...  Again as mentioned above there is two trains s...
# 7281       2.0 ...  If coming by metro from DCA Airport take the y...
# 7283       1.0 ...  We are located in between the Mt Vernon Square...
# 7599       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 8152       1.0 ...  The best way to get around is by train or taxi...
# 8281       1.0 ...  The best way to get around is by train or taxi...
# 7165       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6961       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6942       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6797       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6689       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
#
#       weekly_price                                     xl_picture_url zipcode  \
# 3832           NaN  https://a0.muscache.com/im/pictures/e2ae0b5e-0...   20012
# 7787           NaN  https://a0.muscache.com/im/pictures/0c0630b4-0...   other
# 6335           NaN                                                NaN   other
# 7281           NaN                                                NaN   20009
# 7283           NaN                                                NaN   20001
# 7599           NaN                                                NaN   20016
# 8152           NaN                                                NaN   20011
# 8281           NaN                                                NaN   20011
# 7165           NaN                                                NaN   20016
# 6961           NaN                                                NaN   20016
# 6942           NaN                                                NaN   20016
# 6797           NaN                                                NaN   20016
# 6689           NaN                                                NaN   20016
#
#       year year_2015 year_2018 q_2 q_3 q_4
# 3832  2017         0         0   1   0   0
# 7787  2017         0         0   1   0   0
# 6335  2018         0         1   1   0   0
# 7281  2018         0         1   1   0   0
# 7283  2018         0         1   1   0   0
# 7599  2018         0         1   1   0   0
# 8152  2018         0         1   1   0   0
# 8281  2018         0         1   1   0   0
# 7165  2018         0         1   1   0   0
# 6961  2018         0         1   0   1   0
# 6942  2018         0         1   0   1   0
# 6797  2018         0         1   0   1   0
# 6689  2018         0         1   0   0   1
#
# [13 rows x 102 columns]

# %%
# look at outliers (low)

dflist[dflist['price'] < 10]
# Out:
#                                                  access  accommodates  \
# 3832  Front and back screened-in porches, yard, Wifi...             5
# 7787  You will have access to the backyard, basement...             2
# 6335  You will have access to the backyard, basement...             2
# 7281  You will have access to the living room and en...             5
# 7283                                    Shared bathroom             2
# 7599  At the moment guests only have access to the r...             2
# 8152  The room has a lock on the door, plenty of spa...             3
# 8281  The room has a lock on the door, plenty of spa...             3
# 7165  At the moment guests only have access to the r...             2
# 6961  At the moment guests only have access to the r...             2
# 6942  At the moment guests only have access to the r...             2
# 6797  At the moment guests only have access to the r...             2
# 6689  At the moment guests only have access to the r...             2
#
#                                               amenities  availability_30  \
# 3832  {TV,"Cable TV",Internet,"Wireless Internet","A...               24
# 7787  {TV,Internet,"Wireless Internet","Air conditio...               24
# 6335  {Internet,Wifi,"Air conditioning",Kitchen,"Fre...                0
# 7281  {TV,"Cable TV",Wifi,"Air conditioning",Kitchen...                0
# 7283  {Wifi,"Air conditioning",Kitchen,Heating,Washe...                0
# 7599  {TV,"Air conditioning",Heating,Essentials,Sham...               10
# 8152  {TV,Wifi,"Air conditioning",Pool,Kitchen,Gym,E...               29
# 8281  {TV,"Cable TV",Wifi,"Air conditioning",Pool,Ki...               15
# 7165  {TV,"Air conditioning",Heating,Essentials,Sham...                4
# 6961  {TV,"Air conditioning",Heating,Essentials,Sham...                8
# 6942  {TV,"Air conditioning",Heating,Essentials,Sham...               22
# 6797  {TV,"Air conditioning",Heating,Essentials,Sham...               14
# 6689  {TV,"Air conditioning",Heating,Essentials,Sham...                0
#
#       availability_365  availability_60  availability_90  bathrooms  bed_type  \
# 3832               340               48               68        1.5  Real Bed
# 7787               359               54               84        1.0  Real Bed
# 6335                 0                0                0        1.0  Real Bed
# 7281                99                0                0        2.0  Real Bed
# 7283                13                0               13        1.0  Real Bed
# 7599                50               23               50        1.0  Real Bed
# 8152               364               59               89        1.0  Real Bed
# 8281               350               45               75        1.0  Real Bed
# 7165                49               24               49        1.0  Real Bed
# 6961                61               31               61        1.0  Real Bed
# 6942                78               48               78        1.0  Real Bed
# 6797                72               42               72        1.0  Real Bed
# 6689                 0                0                0        1.0  Real Bed
#
#       bedrooms ...                                            transit  \
# 3832       2.0 ...                Takoma Metro Station 4 blocks away.
# 7787       1.0 ...  Again as mentioned above there is two trains s...
# 6335       1.0 ...  Again as mentioned above there is two trains s...
# 7281       2.0 ...  If coming by metro from DCA Airport take the y...
# 7283       1.0 ...  We are located in between the Mt Vernon Square...
# 7599       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 8152       1.0 ...  The best way to get around is by train or taxi...
# 8281       1.0 ...  The best way to get around is by train or taxi...
# 7165       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6961       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6942       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6797       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
# 6689       1.0 ...  House is 0.9 miles from tenlytown metro, rough...
#
#       weekly_price                                     xl_picture_url zipcode  \
# 3832           NaN  https://a0.muscache.com/im/pictures/e2ae0b5e-0...   20012
# 7787           NaN  https://a0.muscache.com/im/pictures/0c0630b4-0...   other
# 6335           NaN                                                NaN   other
# 7281           NaN                                                NaN   20009
# 7283           NaN                                                NaN   20001
# 7599           NaN                                                NaN   20016
# 8152           NaN                                                NaN   20011
# 8281           NaN                                                NaN   20011
# 7165           NaN                                                NaN   20016
# 6961           NaN                                                NaN   20016
# 6942           NaN                                                NaN   20016
# 6797           NaN                                                NaN   20016
# 6689           NaN                                                NaN   20016
#
#       year year_2015 year_2018 q_2 q_3 q_4
# 3832  2017         0         0   1   0   0
# 7787  2017         0         0   1   0   0
# 6335  2018         0         1   1   0   0
# 7281  2018         0         1   1   0   0
# 7283  2018         0         1   1   0   0
# 7599  2018         0         1   1   0   0
# 8152  2018         0         1   1   0   0
# 8281  2018         0         1   1   0   0
# 7165  2018         0         1   1   0   0
# 6961  2018         0         1   0   1   0
# 6942  2018         0         1   0   1   0
# 6797  2018         0         1   0   1   0
# 6689  2018         0         1   0   0   1
#
# [13 rows x 102 columns]

# %%
# look at outliers (high)

dflist[dflist['price'] > 5000].sort_values(by='price', ascending=False)
# Out:
#                                                  access  accommodates  \
# 8650                                                NaN             4
# 8653                                                NaN             4
# 8275                                                NaN             4
# 8445                                                NaN             4
# 8195                                                NaN             4
# 3596  The home has a staff apartment and catering ki...             8
# 3659  The home has a staff apartment and catering ki...             8
# 3487  The home has a staff apartment and catering ki...             8
# 3499  The home has a staff apartment and catering ki...             8
# 3547  The home has a staff apartment and catering ki...             8
# 3905  The home has a staff apartment and catering ki...             8
# 3588  The home has a staff apartment and catering ki...             8
# 4640                                                NaN            10
# 4178                                                NaN            10
# 3509  The entire home/office is yours. Please be con...            12
# 3453  The entire home/office is yours. Please be con...            12
# 3351  The entire home/office is yours. Please be con...            12
# 7331  The entire home/office is yours. Please be con...            12
# 3365  The entire home/office is yours. Please be con...            12
# 7843  The entire home/office is yours. Please be con...            12
# 3409  The entire home/office is yours. Please be con...            12
# 3741  The entire home/office is yours. Please be con...            12
# 3447  The entire home/office is yours. Please be con...            12
# 5347                                                NaN             5
# 4812                                                NaN            10
# 4749                                                NaN             5
# 5104                                                NaN            10
# 5100                                                NaN            10
# 5245                                                NaN            10
# 4846                                                NaN            10
# 4782                                                NaN             5
# 5419                                                NaN            10
# 4924                                                NaN             5
# 4915                                                NaN            10
# 4852                                                NaN             5
# 5032                                                NaN             5
# 4991                                                NaN            10
# 1204                                                NaN             5
# 4984                                                NaN            10
# 4920                                                NaN             5
# 373                                                 NaN             5
# 4722  Study, dedicated mini-fridge, living room, dis...             2
#
#                                               amenities  availability_30  \
# 8650  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...               18
# 8653  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...               30
# 8275  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...               30
# 8445  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...               30
# 8195  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...               30
# 3596  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 3659  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 3487  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 3499  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 3547  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 3905  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 3588  {TV,Wifi,"Air conditioning",Kitchen,"Indoor fi...               23
# 4640  {TV,"Wireless Internet","Air conditioning",Kit...               25
# 4178  {TV,"Wireless Internet","Air conditioning",Kit...               30
# 3509  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 3453  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 3351  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 7331  {TV,Internet,"Wireless Internet","Air conditio...               30
# 3365  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 7843  {TV,Internet,"Wireless Internet","Air conditio...               30
# 3409  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 3741  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 3447  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...               30
# 5347  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 4812  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 4749  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 5104  {TV,"Wireless Internet","Air conditioning",Kit...               30
# 5100  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 5245  {TV,"Wireless Internet","Air conditioning",Kit...               30
# 4846  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 4782  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 5419  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 4924  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 4915  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 4852  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 5032  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 4991  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 1204  {TV,"Wireless Internet","Air conditioning",Kit...               28
# 4984  {TV,Wifi,"Air conditioning",Kitchen,"Free park...               30
# 4920  {TV,Wifi,"Air conditioning",Kitchen,Gym,Elevat...               28
# 373   {TV,"Wireless Internet","Air conditioning",Kit...                1
# 4722  {TV,"Cable TV",Internet,"Wireless Internet","A...                0
#
#       availability_365  availability_60  availability_90  bathrooms  \
# 8650                78               48               78        1.0
# 8653                90               60               90        1.0
# 8275                90               60               90        1.0
# 8445                90               60               90        1.0
# 8195                90               60               90        1.0
# 3596               358               53               83        6.5
# 3659               358               53               83        6.5
# 3487               358               53               83        6.5
# 3499               358               53               83        6.5
# 3547               358               53               83        6.5
# 3905               358               53               83        6.5
# 3588               358               53               83        6.5
# 4640                85               55               85        3.5
# 4178                90               60               90        3.5
# 3509               365               60               90        4.0
# 3453               365               60               90        4.0
# 3351               365               60               90        4.0
# 7331               365               60               90        4.0
# 3365               365               60               90        4.0
# 7843               365               60               90        4.0
# 3409               365               60               90        4.0
# 3741               365               60               90        4.0
# 3447               365               60               90        4.0
# 5347               363               58               88        3.0
# 4812                90               60               90        4.5
# 4749               363               58               88        3.0
# 5104                90               60               90        4.5
# 5100                90               60               90        4.5
# 5245                90               60               90        4.5
# 4846                90               60               90        4.5
# 4782               363               58               88        3.0
# 5419                90               60               90        4.5
# 4924               363               58               88        3.0
# 4915                90               60               90        4.5
# 4852               363               58               88        3.0
# 5032               363               58               88        3.0
# 4991                90               60               90        4.5
# 1204               363               58               88        3.0
# 4984                90               60               90        4.5
# 4920               363               58               88        3.0
# 373                314                9               39        3.0
# 4722                60               30               60        1.0
#
#            bed_type  bedrooms ...  \
# 8650       Real Bed       2.0 ...
# 8653       Real Bed       2.0 ...
# 8275       Real Bed       2.0 ...
# 8445       Real Bed       2.0 ...
# 8195       Real Bed       2.0 ...
# 3596       Real Bed       4.0 ...
# 3659       Real Bed       4.0 ...
# 3487       Real Bed       4.0 ...
# 3499       Real Bed       4.0 ...
# 3547       Real Bed       4.0 ...
# 3905       Real Bed       4.0 ...
# 3588       Real Bed       4.0 ...
# 4640       Real Bed       3.0 ...
# 4178       Real Bed       3.0 ...
# 3509       Real Bed       5.0 ...
# 3453       Real Bed       5.0 ...
# 3351       Real Bed       5.0 ...
# 7331       Real Bed       5.0 ...
# 3365       Real Bed       5.0 ...
# 7843       Real Bed       5.0 ...
# 3409       Real Bed       5.0 ...
# 3741       Real Bed       5.0 ...
# 3447       Real Bed       5.0 ...
# 5347       Real Bed       3.0 ...
# 4812       Real Bed       5.0 ...
# 4749       Real Bed       3.0 ...
# 5104       Real Bed       5.0 ...
# 5100       Real Bed       5.0 ...
# 5245       Real Bed       5.0 ...
# 4846       Real Bed       5.0 ...
# 4782       Real Bed       3.0 ...
# 5419       Real Bed       5.0 ...
# 4924       Real Bed       3.0 ...
# 4915       Real Bed       5.0 ...
# 4852       Real Bed       3.0 ...
# 5032       Real Bed       3.0 ...
# 4991       Real Bed       5.0 ...
# 1204       Real Bed       3.0 ...
# 4984       Real Bed       5.0 ...
# 4920       Real Bed       3.0 ...
# 373        Real Bed       3.0 ...
# 4722  Pull-out Sofa       1.0 ...
#
#                                                 transit  weekly_price  \
# 8650                                                NaN           NaN
# 8653                                                NaN           NaN
# 8275                                                NaN           NaN
# 8445                                                NaN           NaN
# 8195                                                NaN           NaN
# 3596                                                NaN           NaN
# 3659                                                NaN           NaN
# 3487                                                NaN           NaN
# 3499                                                NaN           NaN
# 3547                                                NaN           NaN
# 3905                                                NaN           NaN
# 3588                                                NaN           NaN
# 4640                                                NaN           NaN
# 4178                                                NaN           NaN
# 3509  You can walk to almost everything in Washingto...           NaN
# 3453  You can walk to almost everything in Washingto...           NaN
# 3351  You can walk to almost everything in Washingto...           NaN
# 7331  You can walk to almost everything in Washingto...           NaN
# 3365  You can walk to almost everything in Washingto...           NaN
# 7843  You can walk to almost everything including th...           NaN
# 3409  You can walk to almost everything in Washingto...           NaN
# 3741  You can walk to almost everything in Washingto...           NaN
# 3447  You can walk to almost everything in Washingto...           NaN
# 5347                                                NaN           NaN
# 4812                                                NaN           NaN
# 4749                                                NaN           NaN
# 5104                                                NaN           NaN
# 5100                                                NaN           NaN
# 5245                                                NaN           NaN
# 4846                                                NaN           NaN
# 4782                                                NaN           NaN
# 5419                                                NaN           NaN
# 4924                                                NaN           NaN
# 4915                                                NaN           NaN
# 4852                                                NaN           NaN
# 5032                                                NaN           NaN
# 4991                                                NaN           NaN
# 1204                                                NaN           NaN
# 4984                                                NaN           NaN
# 4920                                                NaN           NaN
# 373                                                 NaN           NaN
# 4722  I am 2 blocks from a bus route that goes to Un...           NaN
#
#                                          xl_picture_url zipcode  year  \
# 8650                                                NaN   20024  2018
# 8653                                                NaN   20024  2018
# 8275                                                NaN   20024  2018
# 8445                                                NaN   20024  2018
# 8195                                                NaN   20024  2018
# 3596                                                NaN   20007  2018
# 3659                                                NaN   20007  2018
# 3487                                                NaN   20007  2018
# 3499                                                NaN   20007  2018
# 3547                                                NaN   20007  2018
# 3905                                                NaN   20007  2018
# 3588                                                NaN   20007  2018
# 4640                                                NaN   20002  2017
# 4178                                                NaN   20002  2017
# 3509                                                NaN   20003  2018
# 3453                                                NaN   20003  2018
# 3351                                                NaN   20003  2018
# 7331                                                NaN   20003  2017
# 3365                                                NaN   20003  2018
# 7843                                                NaN   20003  2017
# 3409                                                NaN   20003  2018
# 3741                                                NaN   20003  2018
# 3447                                                NaN   20003  2018
# 5347                                                NaN   20001  2018
# 4812                                                NaN   20009  2018
# 4749                                                NaN   20001  2018
# 5104                                                NaN   20009  2017
# 5100                                                NaN   20009  2018
# 5245                                                NaN   20009  2017
# 4846                                                NaN   20009  2018
# 4782                                                NaN   20001  2018
# 5419                                                NaN   20009  2018
# 4924                                                NaN   20001  2018
# 4915                                                NaN   20009  2018
# 4852                                                NaN   20001  2018
# 5032                                                NaN   20001  2018
# 4991                                                NaN   20009  2018
# 1204                                                NaN   20001  2017
# 4984                                                NaN   20009  2018
# 4920                                                NaN   20001  2018
# 373                                                 NaN   20001  2017
# 4722  https://a0.muscache.com/im/pictures/7c648cc9-6...   20002  2017
#
#      year_2015 year_2018 q_2 q_3 q_4
# 8650         0         1   0   1   0
# 8653         0         1   0   1   0
# 8275         0         1   0   0   1
# 8445         0         1   0   1   0
# 8195         0         1   0   0   1
# 3596         0         1   0   1   0
# 3659         0         1   1   0   0
# 3487         0         1   0   0   1
# 3499         0         1   0   0   1
# 3547         0         1   0   1   0
# 3905         0         1   1   0   0
# 3588         0         1   0   1   0
# 4640         0         0   0   0   0
# 4178         0         0   1   0   0
# 3509         0         1   1   0   0
# 3453         0         1   0   1   0
# 3351         0         1   0   0   1
# 7331         0         0   1   0   0
# 3365         0         1   0   0   1
# 7843         0         0   0   0   0
# 3409         0         1   0   1   0
# 3741         0         1   1   0   0
# 3447         0         1   0   1   0
# 5347         0         1   1   0   0
# 4812         0         1   0   0   1
# 4749         0         1   0   0   1
# 5104         0         0   1   0   0
# 5100         0         1   1   0   0
# 5245         0         0   0   0   0
# 4846         0         1   0   0   1
# 4782         0         1   0   0   1
# 5419         0         1   1   0   0
# 4924         0         1   0   1   0
# 4915         0         1   0   1   0
# 4852         0         1   0   1   0
# 5032         0         1   1   0   0
# 4991         0         1   0   1   0
# 1204         0         0   1   0   0
# 4984         0         1   0   1   0
# 4920         0         1   0   1   0
# 373          0         0   0   0   0
# 4722         0         0   1   0   0
#
# [42 rows x 102 columns]

# %% [markdown]
# ### Log transformation of price

# %%
# log transformation of price so that high outliers have less impact on model
# Note: Normal distribution of dependent variable is not required for linear regression.
# Normality of the error distribution is one of the assumptions of linear regression, 
# but not normality of dependent variable.
# see https://stats.stackexchange.com/questions/298/in-linear-regression-when-is-it-appropriate-to-use-the-log-of-an-independent-va

# %%
# drop 13 records where price = 0 (this is not a valid price, and taking log of 0 will result in error)
dflist = dflist[dflist['price'] > 0]

# create 'log_price' with log transformation of price, to be target variable
dflist['log_price'] = np.log(dflist['price'])

# %%
dflist['log_price'].describe()
# Out:
# count    82942.000000
# mean         4.926218
# std          0.831365
# min          2.302585
# 25%          4.382027
# 50%          4.787492
# 75%          5.298317
# max          9.472705
# Name: log_price, dtype: float64

# %%
dflist['log_price'].hist();

# %% [markdown]
# ### Correlation heatmaps for numeric variables

# %%
# ref: https://seaborn.pydata.org/examples/many_pairwise_correlations.html

sns.set(style="white")

# Compute the correlation matrix
corr = dflist.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, #vmax=.3, 
            center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
plt.figure(figsize=(6,12))
plt.title('Correlation with price', fontsize=18)
sns.heatmap(dflist.corr()[['price']].sort_values(by='price', ascending=False), cmap="BrBG", center=0, annot=True);

# %%
plt.figure(figsize=(6,12))
plt.title('Correlation with log(price)', fontsize=18)
sns.heatmap(dflist.corr()[['log_price']].sort_values(by='log_price', ascending=False), cmap="BrBG", center=0, annot=True);

# %%
dflist.to_csv('data/airbnb01.csv', index=False)
